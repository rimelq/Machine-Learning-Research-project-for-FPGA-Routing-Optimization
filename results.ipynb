# %% [markdown]
# # Results Project 2

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

from plots import *

# %%
results_dir = './some cost/results'

# %% [markdown]
# ## Cost with average
#
# ### Results

# %% [markdown]
# #### Models

# %%
visualize_mse_by_target(results_dir, output_file='sum_target.png')
# Out:
# Plot saved as sum_target.png

# %% [markdown]
# ### Ridge Regression with alpha

# %%
visualize_ridge_results_by_target(results_dir, output_file='sum_alpha.png')
# Out:
# Plot saved as sum_alpha.png

# %% [markdown]
# ### Weighted Results
#
# #### Models

# %%
weigthed_results_dir = './some cost/weighted_results'

# %%
visualize_mse_by_target(weigthed_results_dir, output_file='sum_target_weighted.png')
# Out:
# Plot saved as sum_target_weighted.png

# %%
visualize_ridge_results_by_target(weigthed_results_dir, output_file='sum_alpha_weighted.png')
# Out:
# Plot saved as sum_alpha_weighted.png

# %% [markdown]
# ## Cost with sum

# %%
results_dir = './average cost/results'

# %% [markdown]
# ### Results

# %%
visualize_mse_by_target_avg(results_dir, output_file='avg_target.png')
# Out:
# Plot saved as avg_target.png

# %%
visualize_ridge_results_by_target_avg(results_dir, output_file='avg_alpha.png')
# Out:
# Plot saved as avg_alpha.png

# %% [markdown]
# ### Weighted Results

# %%
weigthed_results_dir = './average cost/weighted_results'

# %%
visualize_mse_by_target_avg(weigthed_results_dir, output_file='avg_target_weigthed.png')
# Out:
# Plot saved as avg_target_weigthed.png
